# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadParsaTheFirst/My-HWs/blob/main/Machine%20Vision%20LAB/LAB2/LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 2
# ## MohammadParsa Dini
# ### 400101204

# %% [markdown]
# ### Importing Nessecary Libraries

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("running on gpu")
else:
    device = torch.device("cpu")
    print("running on gpu")
# Out:
# running on gpu

# %%
import torch

# Check the available GPUs
print(f"Available GPUs: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Available GPUs: 1
# GPU 0: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# ### (I) Part 1
#
#  In the First section, we will import the data of ozone. Then, we will choose 80 percent of the data for training and the rest of them for testing.
#  Then we will get the data and fit a linear regression model to the train data. At last, we will compute the MSe loss of train and test data.

# %%
file_path = 'C:/Users/USER/Downloads/Lab 2 (1)/ozon.csv'
data = pd.read_csv(file_path)

data
# Out:
#      radiation  temperature  wind  ozone
# 0          190           67   7.4     41
# 1          118           72   8.0     36
# 2          149           74  12.6     12
# 3          313           62  11.5     18
# 4          299           65   8.6     23
# ..         ...          ...   ...    ...
# 106         20           63  16.6     14
# 107        193           70   6.9     30
# 108        191           75  14.3     14
# 109        131           76   8.0     18
# 110        223           68  11.5     20
#
# [111 rows x 4 columns]

# %%
x = data.drop('ozone', axis=1)
y = data['ozone']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f'shaep of x       : {x.shape}')
print(f'shaep of y       : {y.shape}')
print(f'shape of x_train : {x_train.shape} ')
print(f'shape of x_test  : {x_test.shape} ')
print(f'shape of y_train : {y_train.shape} ')
print(f'shape of y_test  : {y_test.shape} ')
# Out:
# shaep of x       : (111, 3)
# shaep of y       : (111,)
# shape of x_train : (88, 3)
# shape of x_test  : (23, 3)
# shape of y_train : (88,)
# shape of y_test  : (23,)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
coeffs , intercept = model.coef_, model.intercept_

print(f'coefficient of the linear regression model :: {coeffs}')
print(f'intercept of the linear regression model   :: {intercept}')
# Out:
# coefficient of the linear regression model :: [ 0.06339674  1.6229136  -3.45349018]
# intercept of the linear regression model   :: -60.99239108927823

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test_pred, y_test)

print(f'MSE error for train data :: {mse_train}')
print(f'MSE error for test data  :: {mse_test}')
# Out:
# MSE error for train data :: 481.62978844934446
# MSE error for test data  :: 245.17289877643475

# %%
vars = np.linspace(0, 50, 50)
mse_trains = []
mse_tests = []

for var in vars:
    noise = np.random.normal(0, np.sqrt(var), size=y.shape)
    y_noisy = y + noise
    x_train, x_test, y_train, y_test = train_test_split(x,y_noisy, test_size=0.2, random_state=42)

    model = LinearRegression()
    model.fit(x_train, y_train)

    y_pred_test = model.predict(x_test)
    y_pred_train = model.predict(x_train)

    mse_test = mean_squared_error(y_pred_test, y_test)
    mse_train = mean_squared_error(y_pred_train, y_train)
    mse_tests.append(mse_test)
    mse_trains.append(mse_train)

plt.figure(figsize=(12,6))
plt.plot(mse_trains, color='r')
plt.plot(mse_tests, color='b')
plt.legend(['MSE of trained noisy data', 'MSE of tested noisy data'])
plt.grid(True)
plt.xlabel('Noise Variance')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('MSE of trained data with increasing variance from 0 up to 50')
# Out:
# Text(0.5, 1.0, 'MSE of trained data with increasing variance from 0 up to 50')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Assuming 'x' and 'y' are already defined
vars = np.linspace(0, 50, 50)
mse_trains = []
mse_tests = []

for var in vars:
    noise = np.random.normal(0, np.sqrt(var), size=y.shape)
    y_noisy = y + noise

    # Add x^2 features to the matrix x
    x_with_features = np.hstack((x, x**2))

    x_train, x_test, y_train, y_test = train_test_split(x_with_features, y_noisy, test_size=0.2, random_state=42)

    model = LinearRegression()
    model.fit(x_train, y_train)

    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)

    mse_train = mean_squared_error(y_train, y_pred_train)
    mse_test = mean_squared_error(y_test, y_pred_test)

    mse_trains.append(mse_train)
    mse_tests.append(mse_test)

plt.figure(figsize=(12, 6))
plt.plot(vars, mse_trains, color='r')
plt.plot(vars, mse_tests, color='b')
plt.legend(['MSE of trained noisy data', 'MSE of tested noisy data'])
plt.grid(True)
plt.title('MSE of trained data with increasing variance from 0 up to 50 --- added vy x^2')
plt.xlabel('Variance of Gaussian Noise')
plt.ylabel('Mean Squared Error (MSE)')
plt.show()

# %% [markdown]
# ### (II) Part 2:

# %%
import os
import cv2
import numpy as np

file_path = "C:\\Users\\USER\\Downloads\\surprise videos\\surprise videos"
videos = []
labels = []

# List all directories in the file_path
video_dirs = os.listdir(file_path)

for video_dir in video_dirs:
    vid_path = os.path.join(file_path, video_dir)
    if os.path.isdir(vid_path):
        frames = os.listdir(vid_path)
        frames_len = len(frames)
        for i, frame in enumerate(frames):
            img_path = os.path.join(vid_path, frame)
            img = cv2.imread(img_path)
            if frames_len > 1:
                label = i / (frames_len - 1)
            else:
                label = 0
            videos.append(img.flatten())
            labels.append(label)

x = np.array(videos)
y = np.array(labels)
#x_flattened = x.reshape((x.shape[0], -1))

print(f'shape of x               : {x.shape}')
print(f'shape of y               : {y.shape}')
#print(f'flattened image size     : {x_flattened.shape}')
# Out:
# shape of x               : (633, 3240000)
# shape of y               : (633,)
# flattened image size     : (633, 3240000)

# %%
import os
import cv2

X = []
y = []

data_dir =  "C:\\Users\\USER\\Downloads\\surprise videos\\surprise videos"

for folder in os.listdir(data_dir):
    folder_path = os.path.join(data_dir, folder)
    if os.path.isdir(folder_path):
        images = sorted(os.listdir(folder_path))  # Sorting Images
        num_images = len(images)
        # print(num_images)

        for i, img_name in enumerate(images):
            img_path = os.path.join(folder_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Grayscale

            # Loaded well?
            if img is not None:
                img_flattened = img.flatten()  # Vectorizing the X
                X.append(img_flattened)


                # Linear lable from 0 to 1
                label = i / (num_images - 1)
                y.append(label)
            else:
                print(f"Warning: Unable to load image {img_path}")

# %%
X = np.array(X)
y = np.array(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Creating and Fitting LR
model = LinearRegression()
model.fit(X_train, y_train)

#  Predicting on Train/Test set
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

#  MSE on Train/Test set
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

print("Train MSE:", train_mse)
print("Test MSE:", test_mse)
# Out:
# Train MSE: 3.0452411246751654e-28
# Test MSE: 0.004782476166676027

# %%
import math


def apply_mask(image):
    height, width = image.shape
    radius = math.floor(min(height, width) * 0.4)
    center = (width // 2, height // 2)
    mask = np.zeros((height, width), dtype=np.uint8)
    cv2.circle(mask, center, radius, 255, -1)


    masked_image = cv2.bitwise_and(image, image, mask=mask)
    return masked_image

# %%
X= []
y = []
masked =[]

for folder in os.listdir(data_dir):
    folder_path = os.path.join(data_dir, folder)
    if os.path.isdir(folder_path):
        images = sorted(os.listdir(folder_path))  # Sorting
        num_images = len(images)

        for i, img_name in enumerate(images):
            img_path = os.path.join(folder_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # GRayscale

            if img is not None:
                masked_img = apply_mask(img)  # Applyig mask

                X.append(masked_img.flatten() )
                #X.append(masked_img)
                masked.append(masked_img)
                # Linear labels from 0 to 1
                label = i / (num_images - 1)
                y.append(label)
            else:
                print(f"Warning: Unable to load image {img_path}")

# %%
X = np.array(X)
y = np.array(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

#  Creating and fitting LR
model = LinearRegression()
model.fit(X_train, y_train)

#  Predicting on Train/Test set
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

#  MSE on Train/Test set
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

print("Train MSE:", train_mse)
print("Test MSE:", test_mse)
# Out:
# Train MSE: 2.5785897016743194e-28
# Test MSE: 0.004866691545540932

# %%
plt.imshow(masked[30])

# %%
# PCA func
def perform_pca(images, num_components):
    reshaped_images = [img.flatten() for img in images]
    data_matrix = np.array(reshaped_images)
    mean_face = np.mean(data_matrix, axis=0)
    centered_data = data_matrix - mean_face

    A = np.array(centered_data).T  # Transpose to get covariance matrix
    AtA = np.dot(A.T, A)  # Covariance matrix
    eigvals, eigvecs_v = np.linalg.eig(AtA)

    sorted_indices = np.argsort(eigvals)[::-1]  # Sort eigenvalues
    top_eigvecs_v = eigvecs_v[:, sorted_indices[:num_components]]  # Top components

    top_eigvecs_u = np.dot(A, top_eigvecs_v)  # Actual eigenfaces
    for i in range(num_components):
        top_eigvecs_u[:, i] /= np.linalg.norm(top_eigvecs_u[:, i])  # Normalize

    return mean_face, top_eigvecs_u

# DR of data
def project_to_pca_space(images, mean_face, eigenfaces):
    projected_data = []
    for img in images:
        img_vector = img.flatten() - mean_face
        weights = np.dot(eigenfaces.T, img_vector)  # Projections onto eigenfaces
        projected_data.append(weights)
    return np.array(projected_data)

# %%
# Apply PCA
num_components = 10  # Main coefficients
mean_face, eigenfaces = perform_pca(X_train, num_components)

# DR
X_train_pca = project_to_pca_space(X_train, mean_face, eigenfaces)
X_test_pca = project_to_pca_space(X_test, mean_face, eigenfaces)

# Fitting model
model = LinearRegression()
model.fit(X_train_pca, y_train)

#  Predicting on Train/Test set
y_train_pred = model.predict(X_train_pca)
y_test_pred = model.predict(X_test_pca)

train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

print("Train MSE after PCA:", train_mse)
print("Test MSE after PCA:", test_mse)
# Out:
# Train MSE after PCA: 0.06468476302516789
# Test MSE after PCA: 0.07205313167130775

# %%
train_mse_list = []
test_mse_list = []

# num_components_range = range(1, 46, 10)
num_components_range = range(1, 101 , 20)

for num_components in num_components_range:

    mean_face, eigenfaces = perform_pca(X_train, num_components)


    X_train_pca = project_to_pca_space(X_train, mean_face, eigenfaces)
    X_test_pca = project_to_pca_space(X_test, mean_face, eigenfaces)


    model = LinearRegression()
    model.fit(X_train_pca, y_train)

    y_train_pred = model.predict(X_train_pca)
    y_test_pred = model.predict(X_test_pca)

    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)

    train_mse_list.append(train_mse)
    test_mse_list.append(test_mse)

plt.figure(figsize=(10, 6))
plt.plot(num_components_range, train_mse_list, label='Train MSE')
plt.plot(num_components_range, test_mse_list, label='Test MSE')
plt.xlabel('Number of Principal Components')
plt.ylabel('Mean Squared Error')
plt.title('MSE vs Number of Principal Components')
plt.legend()
plt.grid(True)
plt.show()

# %%
for i, x in enumerate(X):
    print(f"Element {i} shape: {len(x)}")
# Out:
# Element 0 shape: 1080000
# Element 1 shape: 900
# Element 2 shape: 1080000
# Element 3 shape: 900
# Element 4 shape: 1080000
# Element 5 shape: 900
# Element 6 shape: 1080000
# Element 7 shape: 900
# Element 8 shape: 1080000
# Element 9 shape: 900
# Element 10 shape: 1080000
# Element 11 shape: 900
# Element 12 shape: 1080000
# Element 13 shape: 900
# Element 14 shape: 1080000
# Element 15 shape: 900
# Element 16 shape: 1080000
# Element 17 shape: 900
# Element 18 shape: 1080000
# Element 19 shape: 900
# Element 20 shape: 1080000
# Element 21 shape: 900
# Element 22 shape: 1080000
# Element 23 shape: 900
# Element 24 shape: 1080000
# Element 25 shape: 900
# Element 26 shape: 1080000
# Element 27 shape: 900
# Element 28 shape: 1080000
# Element 29 shape: 900
# Element 30 shape: 1080000
# Element 31 shape: 900
# Element 32 shape: 1080000
# Element 33 shape: 900
# Element 34 shape: 1080000
# Element 35 shape: 900
# Element 36 shape: 1080000
# Element 37 shape: 900
# Element 38 shape: 1080000
# Element 39 shape: 900
# Element 40 shape: 1080000
# Element 41 shape: 900
# Element 42 shape: 1080000
# Element 43 shape: 900
# Element 44 shape: 1080000
# Element 45 shape: 900
# Element 46 shape: 1080000
# Element 47 shape: 900
# Element 48 shape: 1080000
# Element 49 shape: 900
# Element 50 shape: 1080000
# Element 51 shape: 900
# Element 52 shape: 1080000
# Element 53 shape: 900
# Element 54 shape: 1080000
# Element 55 shape: 900
# Element 56 shape: 1080000
# Element 57 shape: 900
# Element 58 shape: 1080000
# Element 59 shape: 900
# Element 60 shape: 1080000
# Element 61 shape: 900
# Element 62 shape: 1080000
# Element 63 shape: 900
# Element 64 shape: 1080000
# Element 65 shape: 900
# Element 66 shape: 1080000
# Element 67 shape: 900
# Element 68 shape: 1080000
# Element 69 shape: 900
# Element 70 shape: 1080000
# Element 71 shape: 900
# Element 72 shape: 1080000
# Element 73 shape: 900
# Element 74 shape: 1080000
# Element 75 shape: 900
# Element 76 shape: 1080000
# Element 77 shape: 900
# Element 78 shape: 1080000
# Element 79 shape: 900
# Element 80 shape: 1080000
# Element 81 shape: 900
# Element 82 shape: 1080000
# Element 83 shape: 900
# Element 84 shape: 1080000
# Element 85 shape: 900
# Element 86 shape: 1080000
# Element 87 shape: 900
# Element 88 shape: 1080000
# Element 89 shape: 900
# Element 90 shape: 1080000
# Element 91 shape: 900
# Element 92 shape: 1080000
# Element 93 shape: 900
# Element 94 shape: 1080000
# Element 95 shape: 900
# Element 96 shape: 1080000
# Element 97 shape: 900
# Element 98 shape: 1080000
# Element 99 shape: 900
# Element 100 shape: 1080000
# Element 101 shape: 900
# Element 102 shape: 1080000
# Element 103 shape: 900
# Element 104 shape: 1080000
# Element 105 shape: 900
# Element 106 shape: 1080000
# Element 107 shape: 900
# Element 108 shape: 1080000
# Element 109 shape: 900
# Element 110 shape: 1080000
# Element 111 shape: 900
# Element 112 shape: 1080000
# Element 113 shape: 900
# Element 114 shape: 1080000
# Element 115 shape: 900
# Element 116 shape: 1080000
# Element 117 shape: 900
# Element 118 shape: 1080000
# Element 119 shape: 900
# Element 120 shape: 1080000
# Element 121 shape: 900
# Element 122 shape: 1080000
# Element 123 shape: 900
# Element 124 shape: 1080000
# Element 125 shape: 900
# Element 126 shape: 1080000
# Element 127 shape: 900
# Element 128 shape: 1080000
# Element 129 shape: 900
# Element 130 shape: 1080000
# Element 131 shape: 900
# Element 132 shape: 1080000
# Element 133 shape: 900
# Element 134 shape: 1080000
# Element 135 shape: 900
# Element 136 shape: 1080000
# Element 137 shape: 900
# Element 138 shape: 1080000
# Element 139 shape: 900
# Element 140 shape: 1080000
# Element 141 shape: 900
# Element 142 shape: 1080000
# Element 143 shape: 900
# Element 144 shape: 1080000
# Element 145 shape: 900
# Element 146 shape: 1080000
# Element 147 shape: 900
# Element 148 shape: 1080000
# Element 149 shape: 900
# Element 150 shape: 1080000
# Element 151 shape: 900
# Element 152 shape: 1080000
# Element 153 shape: 900
# Element 154 shape: 1080000
# Element 155 shape: 900
# Element 156 shape: 1080000
# Element 157 shape: 900
# Element 158 shape: 1080000
# Element 159 shape: 900
# Element 160 shape: 1080000
# Element 161 shape: 900
# Element 162 shape: 1080000
# Element 163 shape: 900
# Element 164 shape: 1080000
# Element 165 shape: 900
# Element 166 shape: 1080000
# Element 167 shape: 900
# Element 168 shape: 1080000
# Element 169 shape: 900
# Element 170 shape: 1080000
# Element 171 shape: 900
# Element 172 shape: 1080000
# Element 173 shape: 900
# Element 174 shape: 1080000
# Element 175 shape: 900
# Element 176 shape: 1080000
# Element 177 shape: 900
# Element 178 shape: 1080000
# Element 179 shape: 900
# Element 180 shape: 1080000
# Element 181 shape: 900
# Element 182 shape: 1080000
# Element 183 shape: 900
# Element 184 shape: 1080000
# Element 185 shape: 900
# Element 186 shape: 1080000
# Element 187 shape: 900
# Element 188 shape: 1080000
# Element 189 shape: 900
# Element 190 shape: 1080000
# Element 191 shape: 900
# Element 192 shape: 1080000
# Element 193 shape: 900
# Element 194 shape: 1080000
# Element 195 shape: 900
# Element 196 shape: 1080000
# Element 197 shape: 900
# Element 198 shape: 1080000
# Element 199 shape: 900
# Element 200 shape: 1080000
# Element 201 shape: 900
# Element 202 shape: 1080000
# Element 203 shape: 900
# Element 204 shape: 1080000
# Element 205 shape: 900
# Element 206 shape: 1080000
# Element 207 shape: 900
# Element 208 shape: 1080000
# Element 209 shape: 900
# Element 210 shape: 1080000
# Element 211 shape: 900
# Element 212 shape: 1080000
# Element 213 shape: 900
# Element 214 shape: 1080000
# Element 215 shape: 900
# Element 216 shape: 1080000
# Element 217 shape: 900
# Element 218 shape: 1080000
# Element 219 shape: 900
# Element 220 shape: 1080000
# Element 221 shape: 900
# Element 222 shape: 1080000
# Element 223 shape: 900
# Element 224 shape: 1080000
# Element 225 shape: 900
# Element 226 shape: 1080000
# Element 227 shape: 900
# Element 228 shape: 1080000
# Element 229 shape: 900
# Element 230 shape: 1080000
# Element 231 shape: 900
# Element 232 shape: 1080000
# Element 233 shape: 900
# Element 234 shape: 1080000
# Element 235 shape: 900
# Element 236 shape: 1080000
# Element 237 shape: 900
# Element 238 shape: 1080000
# Element 239 shape: 900
# Element 240 shape: 1080000
# Element 241 shape: 900
# Element 242 shape: 1080000
# Element 243 shape: 900
# Element 244 shape: 1080000
# Element 245 shape: 900
# Element 246 shape: 1080000
# Element 247 shape: 900
# Element 248 shape: 1080000
# Element 249 shape: 900
# Element 250 shape: 1080000
# Element 251 shape: 900
# Element 252 shape: 1080000
# Element 253 shape: 900
# Element 254 shape: 1080000
# Element 255 shape: 900
# Element 256 shape: 1080000
# Element 257 shape: 900
# Element 258 shape: 1080000
# Element 259 shape: 900
# Element 260 shape: 1080000
# Element 261 shape: 900
# Element 262 shape: 1080000
# Element 263 shape: 900
# Element 264 shape: 1080000
# Element 265 shape: 900
# Element 266 shape: 1080000
# Element 267 shape: 900
# Element 268 shape: 1080000
# Element 269 shape: 900
# Element 270 shape: 1080000
# Element 271 shape: 900
# Element 272 shape: 1080000
# Element 273 shape: 900
# Element 274 shape: 1080000
# Element 275 shape: 900
# Element 276 shape: 1080000
# Element 277 shape: 900
# Element 278 shape: 1080000
# Element 279 shape: 900
# Element 280 shape: 1080000
# Element 281 shape: 900
# Element 282 shape: 1080000
# Element 283 shape: 900
# Element 284 shape: 1080000
# Element 285 shape: 900
# Element 286 shape: 1080000
# Element 287 shape: 900
# Element 288 shape: 1080000
# Element 289 shape: 900
# Element 290 shape: 1080000
# Element 291 shape: 900
# Element 292 shape: 1080000
# Element 293 shape: 900
# Element 294 shape: 1080000
# Element 295 shape: 900
# Element 296 shape: 1080000
# Element 297 shape: 900
# Element 298 shape: 1080000
# Element 299 shape: 900
# Element 300 shape: 1080000
# Element 301 shape: 900
# Element 302 shape: 1080000
# Element 303 shape: 900
# Element 304 shape: 1080000
# Element 305 shape: 900
# Element 306 shape: 1080000
# Element 307 shape: 900
# Element 308 shape: 1080000
# Element 309 shape: 900
# Element 310 shape: 1080000
# Element 311 shape: 900
# Element 312 shape: 1080000
# Element 313 shape: 900
# Element 314 shape: 1080000
# Element 315 shape: 900
# Element 316 shape: 1080000
# Element 317 shape: 900
# Element 318 shape: 1080000
# Element 319 shape: 900
# Element 320 shape: 1080000
# Element 321 shape: 900
# Element 322 shape: 1080000
# Element 323 shape: 900
# Element 324 shape: 1080000
# Element 325 shape: 900
# Element 326 shape: 1080000
# Element 327 shape: 900
# Element 328 shape: 1080000
# Element 329 shape: 900
# Element 330 shape: 1080000
# Element 331 shape: 900
# Element 332 shape: 1080000
# Element 333 shape: 900
# Element 334 shape: 1080000
# Element 335 shape: 900
# Element 336 shape: 1080000
# Element 337 shape: 900
# Element 338 shape: 1080000
# Element 339 shape: 900
# Element 340 shape: 1080000
# Element 341 shape: 900
# Element 342 shape: 1080000
# Element 343 shape: 900
# Element 344 shape: 1080000
# Element 345 shape: 900
# Element 346 shape: 1080000
# Element 347 shape: 900
# Element 348 shape: 1080000
# Element 349 shape: 900
# Element 350 shape: 1080000
# Element 351 shape: 900
# Element 352 shape: 1080000
# Element 353 shape: 900
# Element 354 shape: 1080000
# Element 355 shape: 900
# Element 356 shape: 1080000
# Element 357 shape: 900
# Element 358 shape: 1080000
# Element 359 shape: 900
# Element 360 shape: 1080000
# Element 361 shape: 900
# Element 362 shape: 1080000
# Element 363 shape: 900
# Element 364 shape: 1080000
# Element 365 shape: 900
# Element 366 shape: 1080000
# Element 367 shape: 900
# Element 368 shape: 1080000
# Element 369 shape: 900
# Element 370 shape: 1080000
# Element 371 shape: 900
# Element 372 shape: 1080000
# Element 373 shape: 900
# Element 374 shape: 1080000
# Element 375 shape: 900
# Element 376 shape: 1080000
# Element 377 shape: 900
# Element 378 shape: 1080000
# Element 379 shape: 900
# Element 380 shape: 1080000
# Element 381 shape: 900
# Element 382 shape: 1080000
# Element 383 shape: 900
# Element 384 shape: 1080000
# Element 385 shape: 900
# Element 386 shape: 1080000
# Element 387 shape: 900
# Element 388 shape: 1080000
# Element 389 shape: 900
# Element 390 shape: 1080000
# Element 391 shape: 900
# Element 392 shape: 1080000
# Element 393 shape: 900
# Element 394 shape: 1080000
# Element 395 shape: 900
# Element 396 shape: 1080000
# Element 397 shape: 900
# Element 398 shape: 1080000
# Element 399 shape: 900
# Element 400 shape: 1080000
# Element 401 shape: 900
# Element 402 shape: 1080000
# Element 403 shape: 900
# Element 404 shape: 1080000
# Element 405 shape: 900
# Element 406 shape: 1080000
# Element 407 shape: 900
# Element 408 shape: 1080000
# Element 409 shape: 900
# Element 410 shape: 1080000
# Element 411 shape: 900
# Element 412 shape: 1080000
# Element 413 shape: 900
# Element 414 shape: 1080000
# Element 415 shape: 900
# Element 416 shape: 1080000
# Element 417 shape: 900
# Element 418 shape: 1080000
# Element 419 shape: 900
# Element 420 shape: 1080000
# Element 421 shape: 900
# Element 422 shape: 1080000
# Element 423 shape: 900
# Element 424 shape: 1080000
# Element 425 shape: 900
# Element 426 shape: 1080000
# Element 427 shape: 900
# Element 428 shape: 1080000
# Element 429 shape: 900
# Element 430 shape: 1080000
# Element 431 shape: 900
# Element 432 shape: 1080000
# Element 433 shape: 900
# Element 434 shape: 1080000
# Element 435 shape: 900
# Element 436 shape: 1080000
# Element 437 shape: 900
# Element 438 shape: 1080000
# Element 439 shape: 900
# Element 440 shape: 1080000
# Element 441 shape: 900
# Element 442 shape: 1080000
# Element 443 shape: 900
# Element 444 shape: 1080000
# Element 445 shape: 900
# Element 446 shape: 1080000
# Element 447 shape: 900
# Element 448 shape: 1080000
# Element 449 shape: 900
# Element 450 shape: 1080000
# Element 451 shape: 900
# Element 452 shape: 1080000
# Element 453 shape: 900
# Element 454 shape: 1080000
# Element 455 shape: 900
# Element 456 shape: 1080000
# Element 457 shape: 900
# Element 458 shape: 1080000
# Element 459 shape: 900
# Element 460 shape: 1080000
# Element 461 shape: 900
# Element 462 shape: 1080000
# Element 463 shape: 900
# Element 464 shape: 1080000
# Element 465 shape: 900
# Element 466 shape: 1080000
# Element 467 shape: 900
# Element 468 shape: 1080000
# Element 469 shape: 900
# Element 470 shape: 1080000
# Element 471 shape: 900
# Element 472 shape: 1080000
# Element 473 shape: 900
# Element 474 shape: 1080000
# Element 475 shape: 900
# Element 476 shape: 1080000
# Element 477 shape: 900
# Element 478 shape: 1080000
# Element 479 shape: 900
# Element 480 shape: 1080000
# Element 481 shape: 900
# Element 482 shape: 1080000
# Element 483 shape: 900
# Element 484 shape: 1080000
# Element 485 shape: 900
# Element 486 shape: 1080000
# Element 487 shape: 900
# Element 488 shape: 1080000
# Element 489 shape: 900
# Element 490 shape: 1080000
# Element 491 shape: 900
# Element 492 shape: 1080000
# Element 493 shape: 900
# Element 494 shape: 1080000
# Element 495 shape: 900
# Element 496 shape: 1080000
# Element 497 shape: 900
# Element 498 shape: 1080000
# Element 499 shape: 900
# Element 500 shape: 1080000
# Element 501 shape: 900
# Element 502 shape: 1080000
# Element 503 shape: 900
# Element 504 shape: 1080000
# Element 505 shape: 900
# Element 506 shape: 1080000
# Element 507 shape: 900
# Element 508 shape: 1080000
# Element 509 shape: 900
# Element 510 shape: 1080000
# Element 511 shape: 900
# Element 512 shape: 1080000
# Element 513 shape: 900
# Element 514 shape: 1080000
# Element 515 shape: 900
# Element 516 shape: 1080000
# Element 517 shape: 900
# Element 518 shape: 1080000
# Element 519 shape: 900
# Element 520 shape: 1080000
# Element 521 shape: 900
# Element 522 shape: 1080000
# Element 523 shape: 900
# Element 524 shape: 1080000
# Element 525 shape: 900
# Element 526 shape: 1080000
# Element 527 shape: 900
# Element 528 shape: 1080000
# Element 529 shape: 900
# Element 530 shape: 1080000
# Element 531 shape: 900
# Element 532 shape: 1080000
# Element 533 shape: 900
# Element 534 shape: 1080000
# Element 535 shape: 900
# Element 536 shape: 1080000
# Element 537 shape: 900
# Element 538 shape: 1080000
# Element 539 shape: 900
# Element 540 shape: 1080000
# Element 541 shape: 900
# Element 542 shape: 1080000
# Element 543 shape: 900
# Element 544 shape: 1080000
# Element 545 shape: 900
# Element 546 shape: 1080000
# Element 547 shape: 900
# Element 548 shape: 1080000
# Element 549 shape: 900
# Element 550 shape: 1080000
# Element 551 shape: 900
# Element 552 shape: 1080000
# Element 553 shape: 900
# Element 554 shape: 1080000
# Element 555 shape: 900
# Element 556 shape: 1080000
# Element 557 shape: 900
# Element 558 shape: 1080000
# Element 559 shape: 900
# Element 560 shape: 1080000
# Element 561 shape: 900
# Element 562 shape: 1080000
# Element 563 shape: 900
# Element 564 shape: 1080000
# Element 565 shape: 900
# Element 566 shape: 1080000
# Element 567 shape: 900
# Element 568 shape: 1080000
# Element 569 shape: 900
# Element 570 shape: 1080000
# Element 571 shape: 900
# Element 572 shape: 1080000
# Element 573 shape: 900
# Element 574 shape: 1080000
# Element 575 shape: 900
# Element 576 shape: 1080000
# Element 577 shape: 900
# Element 578 shape: 1080000
# Element 579 shape: 900
# Element 580 shape: 1080000
# Element 581 shape: 900
# Element 582 shape: 1080000
# Element 583 shape: 900
# Element 584 shape: 1080000
# Element 585 shape: 900
# Element 586 shape: 1080000
# Element 587 shape: 900
# Element 588 shape: 1080000
# Element 589 shape: 900
# Element 590 shape: 1080000
# Element 591 shape: 900
# Element 592 shape: 1080000
# Element 593 shape: 900
# Element 594 shape: 1080000
# Element 595 shape: 900
# Element 596 shape: 1080000
# Element 597 shape: 900
# Element 598 shape: 1080000
# Element 599 shape: 900
# Element 600 shape: 1080000
# Element 601 shape: 900
# Element 602 shape: 1080000
# Element 603 shape: 900
# Element 604 shape: 1080000
# Element 605 shape: 900
# Element 606 shape: 1080000
# Element 607 shape: 900
# Element 608 shape: 1080000
# Element 609 shape: 900
# Element 610 shape: 1080000
# Element 611 shape: 900
# Element 612 shape: 1080000
# Element 613 shape: 900
# Element 614 shape: 1080000
# Element 615 shape: 900
# Element 616 shape: 1080000
# Element 617 shape: 900
# Element 618 shape: 1080000
# Element 619 shape: 900
# Element 620 shape: 1080000
# Element 621 shape: 900
# Element 622 shape: 1080000
# Element 623 shape: 900
# Element 624 shape: 1080000
# Element 625 shape: 900
# Element 626 shape: 1080000
# Element 627 shape: 900
# Element 628 shape: 1080000
# Element 629 shape: 900
# Element 630 shape: 1080000
# Element 631 shape: 900
# Element 632 shape: 1080000
# Element 633 shape: 900
# Element 634 shape: 1080000
# Element 635 shape: 900
# Element 636 shape: 1080000
# Element 637 shape: 900
# Element 638 shape: 1080000
# Element 639 shape: 900
# Element 640 shape: 1080000
# Element 641 shape: 900
# Element 642 shape: 1080000
# Element 643 shape: 900
# Element 644 shape: 1080000
# Element 645 shape: 900
# Element 646 shape: 1080000
# Element 647 shape: 900
# Element 648 shape: 1080000
# Element 649 shape: 900
# Element 650 shape: 1080000
# Element 651 shape: 900
# Element 652 shape: 1080000
# Element 653 shape: 900
# Element 654 shape: 1080000
# Element 655 shape: 900
# Element 656 shape: 1080000
# Element 657 shape: 900
# Element 658 shape: 1080000
# Element 659 shape: 900
# Element 660 shape: 1080000
# Element 661 shape: 900
# Element 662 shape: 1080000
# Element 663 shape: 900
# Element 664 shape: 1080000
# Element 665 shape: 900
# Element 666 shape: 1080000
# Element 667 shape: 900
# Element 668 shape: 1080000
# Element 669 shape: 900
# Element 670 shape: 1080000
# Element 671 shape: 900
# Element 672 shape: 1080000
# Element 673 shape: 900
# Element 674 shape: 1080000
# Element 675 shape: 900
# Element 676 shape: 1080000
# Element 677 shape: 900
# Element 678 shape: 1080000
# Element 679 shape: 900
# Element 680 shape: 1080000
# Element 681 shape: 900
# Element 682 shape: 1080000
# Element 683 shape: 900
# Element 684 shape: 1080000
# Element 685 shape: 900
# Element 686 shape: 1080000
# Element 687 shape: 900
# Element 688 shape: 1080000
# Element 689 shape: 900
# Element 690 shape: 1080000
# Element 691 shape: 900
# Element 692 shape: 1080000
# Element 693 shape: 900
# Element 694 shape: 1080000
# Element 695 shape: 900
# Element 696 shape: 1080000
# Element 697 shape: 900
# Element 698 shape: 1080000
# Element 699 shape: 900
# Element 700 shape: 1080000
# Element 701 shape: 900
# Element 702 shape: 1080000
# Element 703 shape: 900
# Element 704 shape: 1080000
# Element 705 shape: 900
# Element 706 shape: 1080000
# Element 707 shape: 900
# Element 708 shape: 1080000
# Element 709 shape: 900
# Element 710 shape: 1080000
# Element 711 shape: 900
# Element 712 shape: 1080000
# Element 713 shape: 900
# Element 714 shape: 1080000
# Element 715 shape: 900
# Element 716 shape: 1080000
# Element 717 shape: 900
# Element 718 shape: 1080000
# Element 719 shape: 900
# Element 720 shape: 1080000
# Element 721 shape: 900
# Element 722 shape: 1080000
# Element 723 shape: 900
# Element 724 shape: 1080000
# Element 725 shape: 900
# Element 726 shape: 1080000
# Element 727 shape: 900
# Element 728 shape: 1080000
# Element 729 shape: 900
# Element 730 shape: 1080000
# Element 731 shape: 900
# Element 732 shape: 1080000
# Element 733 shape: 900
# Element 734 shape: 1080000
# Element 735 shape: 900
# Element 736 shape: 1080000
# Element 737 shape: 900
# Element 738 shape: 1080000
# Element 739 shape: 900
# Element 740 shape: 1080000
# Element 741 shape: 900
# Element 742 shape: 1080000
# Element 743 shape: 900
# Element 744 shape: 1080000
# Element 745 shape: 900
# Element 746 shape: 1080000
# Element 747 shape: 900
# Element 748 shape: 1080000
# Element 749 shape: 900
# Element 750 shape: 1080000
# Element 751 shape: 900
# Element 752 shape: 1080000
# Element 753 shape: 900
# Element 754 shape: 1080000
# Element 755 shape: 900
# Element 756 shape: 1080000
# Element 757 shape: 900
# Element 758 shape: 1080000
# Element 759 shape: 900
# Element 760 shape: 1080000
# Element 761 shape: 900
# Element 762 shape: 1080000
# Element 763 shape: 900
# Element 764 shape: 1080000
# Element 765 shape: 900
# Element 766 shape: 1080000
# Element 767 shape: 900
# Element 768 shape: 1080000
# Element 769 shape: 900
# Element 770 shape: 1080000
# Element 771 shape: 900
# Element 772 shape: 1080000
# Element 773 shape: 900
# Element 774 shape: 1080000
# Element 775 shape: 900
# Element 776 shape: 1080000
# Element 777 shape: 900
# Element 778 shape: 1080000
# Element 779 shape: 900
# Element 780 shape: 1080000
# Element 781 shape: 900
# Element 782 shape: 1080000
# Element 783 shape: 900
# Element 784 shape: 1080000
# Element 785 shape: 900
# Element 786 shape: 1080000
# Element 787 shape: 900
# Element 788 shape: 1080000
# Element 789 shape: 900
# Element 790 shape: 1080000
# Element 791 shape: 900
# Element 792 shape: 1080000
# Element 793 shape: 900
# Element 794 shape: 1080000
# Element 795 shape: 900
# Element 796 shape: 1080000
# Element 797 shape: 900
# Element 798 shape: 1080000
# Element 799 shape: 900
# Element 800 shape: 1080000
# Element 801 shape: 900
# Element 802 shape: 1080000
# Element 803 shape: 900
# Element 804 shape: 1080000
# Element 805 shape: 900
# Element 806 shape: 1080000
# Element 807 shape: 900
# Element 808 shape: 1080000
# Element 809 shape: 900
# Element 810 shape: 1080000
# Element 811 shape: 900
# Element 812 shape: 1080000
# Element 813 shape: 900
# Element 814 shape: 1080000
# Element 815 shape: 900
# Element 816 shape: 1080000
# Element 817 shape: 900
# Element 818 shape: 1080000
# Element 819 shape: 900
# Element 820 shape: 1080000
# Element 821 shape: 900
# Element 822 shape: 1080000
# Element 823 shape: 900
# Element 824 shape: 1080000
# Element 825 shape: 900
# Element 826 shape: 1080000
# Element 827 shape: 900
# Element 828 shape: 1080000
# Element 829 shape: 900
# Element 830 shape: 1080000
# Element 831 shape: 900
# Element 832 shape: 1080000
# Element 833 shape: 900
# Element 834 shape: 1080000
# Element 835 shape: 900
# Element 836 shape: 1080000
# Element 837 shape: 900
# Element 838 shape: 1080000
# Element 839 shape: 900
# Element 840 shape: 1080000
# Element 841 shape: 900
# Element 842 shape: 1080000
# Element 843 shape: 900
# Element 844 shape: 1080000
# Element 845 shape: 900
# Element 846 shape: 1080000
# Element 847 shape: 900
# Element 848 shape: 1080000
# Element 849 shape: 900
# Element 850 shape: 1080000
# Element 851 shape: 900
# Element 852 shape: 1080000
# Element 853 shape: 900
# Element 854 shape: 1080000
# Element 855 shape: 900
# Element 856 shape: 1080000
# Element 857 shape: 900
# Element 858 shape: 1080000
# Element 859 shape: 900
# Element 860 shape: 1080000
# Element 861 shape: 900
# Element 862 shape: 1080000
# Element 863 shape: 900
# Element 864 shape: 1080000
# Element 865 shape: 900
# Element 866 shape: 1080000
# Element 867 shape: 900
# Element 868 shape: 1080000
# Element 869 shape: 900
# Element 870 shape: 1080000
# Element 871 shape: 900
# Element 872 shape: 1080000
# Element 873 shape: 900
# Element 874 shape: 1080000
# Element 875 shape: 900
# Element 876 shape: 1080000
# Element 877 shape: 900
# Element 878 shape: 1080000
# Element 879 shape: 900
# Element 880 shape: 1080000
# Element 881 shape: 900
# Element 882 shape: 1080000
# Element 883 shape: 900
# Element 884 shape: 1080000
# Element 885 shape: 900
# Element 886 shape: 1080000
# Element 887 shape: 900
# Element 888 shape: 1080000
# Element 889 shape: 900
# Element 890 shape: 1080000
# Element 891 shape: 900
# Element 892 shape: 1080000
# Element 893 shape: 900
# Element 894 shape: 1080000
# Element 895 shape: 900
# Element 896 shape: 1080000
# Element 897 shape: 900
# Element 898 shape: 1080000
# Element 899 shape: 900
# Element 900 shape: 1080000
# Element 901 shape: 900
# Element 902 shape: 1080000
# Element 903 shape: 900
# Element 904 shape: 1080000
# Element 905 shape: 900
# Element 906 shape: 1080000
# Element 907 shape: 900
# Element 908 shape: 1080000
# Element 909 shape: 900
# Element 910 shape: 1080000
# Element 911 shape: 900
# Element 912 shape: 1080000
# Element 913 shape: 900
# Element 914 shape: 1080000
# Element 915 shape: 900
# Element 916 shape: 1080000
# Element 917 shape: 900
# Element 918 shape: 1080000
# Element 919 shape: 900
# Element 920 shape: 1080000
# Element 921 shape: 900
# Element 922 shape: 1080000
# Element 923 shape: 900
# Element 924 shape: 1080000
# Element 925 shape: 900
# Element 926 shape: 1080000
# Element 927 shape: 900
# Element 928 shape: 1080000
# Element 929 shape: 900
# Element 930 shape: 1080000
# Element 931 shape: 900
# Element 932 shape: 1080000
# Element 933 shape: 900
# Element 934 shape: 1080000
# Element 935 shape: 900
# Element 936 shape: 1080000
# Element 937 shape: 900
# Element 938 shape: 1080000
# Element 939 shape: 900
# Element 940 shape: 1080000
# Element 941 shape: 900
# Element 942 shape: 1080000
# Element 943 shape: 900
# Element 944 shape: 1080000
# Element 945 shape: 900
# Element 946 shape: 1080000
# Element 947 shape: 900
# Element 948 shape: 1080000
# Element 949 shape: 900
# Element 950 shape: 1080000
# Element 951 shape: 900
# Element 952 shape: 1080000
# Element 953 shape: 900
# Element 954 shape: 1080000
# Element 955 shape: 900
# Element 956 shape: 1080000
# Element 957 shape: 900
# Element 958 shape: 1080000
# Element 959 shape: 900
# Element 960 shape: 1080000
# Element 961 shape: 900
# Element 962 shape: 1080000
# Element 963 shape: 900
# Element 964 shape: 1080000
# Element 965 shape: 900
# Element 966 shape: 1080000
# Element 967 shape: 900
# Element 968 shape: 1080000
# Element 969 shape: 900
# Element 970 shape: 1080000
# Element 971 shape: 900
# Element 972 shape: 1080000
# Element 973 shape: 900
# Element 974 shape: 1080000
# Element 975 shape: 900
# Element 976 shape: 1080000
# Element 977 shape: 900
# Element 978 shape: 1080000
# Element 979 shape: 900
# Element 980 shape: 1080000
# Element 981 shape: 900
# Element 982 shape: 1080000
# Element 983 shape: 900
# Element 984 shape: 1080000
# Element 985 shape: 900
# Element 986 shape: 1080000
# Element 987 shape: 900
# Element 988 shape: 1080000
# Element 989 shape: 900
# Element 990 shape: 1080000
# Element 991 shape: 900
# Element 992 shape: 1080000
# Element 993 shape: 900
# Element 994 shape: 1080000
# Element 995 shape: 900
# Element 996 shape: 1080000
# Element 997 shape: 900
# Element 998 shape: 1080000
# Element 999 shape: 900
# Element 1000 shape: 1080000
# Element 1001 shape: 900
# Element 1002 shape: 1080000
# Element 1003 shape: 900
# Element 1004 shape: 1080000
# Element 1005 shape: 900
# Element 1006 shape: 1080000
# Element 1007 shape: 900
# Element 1008 shape: 1080000
# Element 1009 shape: 900
# Element 1010 shape: 1080000
# Element 1011 shape: 900
# Element 1012 shape: 1080000
# Element 1013 shape: 900
# Element 1014 shape: 1080000
# Element 1015 shape: 900
# Element 1016 shape: 1080000
# Element 1017 shape: 900
# Element 1018 shape: 1080000
# Element 1019 shape: 900
# Element 1020 shape: 1080000
# Element 1021 shape: 900
# Element 1022 shape: 1080000
# Element 1023 shape: 900
# Element 1024 shape: 1080000
# Element 1025 shape: 900
# Element 1026 shape: 1080000
# Element 1027 shape: 900
# Element 1028 shape: 1080000
# Element 1029 shape: 900
# Element 1030 shape: 1080000
# Element 1031 shape: 900
# Element 1032 shape: 1080000
# Element 1033 shape: 900
# Element 1034 shape: 1080000
# Element 1035 shape: 900
# Element 1036 shape: 1080000
# Element 1037 shape: 900
# Element 1038 shape: 1080000
# Element 1039 shape: 900
# Element 1040 shape: 1080000
# Element 1041 shape: 900
# Element 1042 shape: 1080000
# Element 1043 shape: 900
# Element 1044 shape: 1080000
# Element 1045 shape: 900
# Element 1046 shape: 1080000
# Element 1047 shape: 900
# Element 1048 shape: 1080000
# Element 1049 shape: 900
# Element 1050 shape: 1080000
# Element 1051 shape: 900
# Element 1052 shape: 1080000
# Element 1053 shape: 900
# Element 1054 shape: 1080000
# Element 1055 shape: 900
# Element 1056 shape: 1080000
# Element 1057 shape: 900
# Element 1058 shape: 1080000
# Element 1059 shape: 900
# Element 1060 shape: 1080000
# Element 1061 shape: 900
# Element 1062 shape: 1080000
# Element 1063 shape: 900
# Element 1064 shape: 1080000
# Element 1065 shape: 900
# Element 1066 shape: 1080000
# Element 1067 shape: 900
# Element 1068 shape: 1080000
# Element 1069 shape: 900
# Element 1070 shape: 1080000
# Element 1071 shape: 900
# Element 1072 shape: 1080000
# Element 1073 shape: 900
# Element 1074 shape: 1080000
# Element 1075 shape: 900
# Element 1076 shape: 1080000
# Element 1077 shape: 900
# Element 1078 shape: 1080000
# Element 1079 shape: 900
# Element 1080 shape: 1080000
# Element 1081 shape: 900
# Element 1082 shape: 1080000
# Element 1083 shape: 900
# Element 1084 shape: 1080000
# Element 1085 shape: 900
# Element 1086 shape: 1080000
# Element 1087 shape: 900
# Element 1088 shape: 1080000
# Element 1089 shape: 900
# Element 1090 shape: 1080000
# Element 1091 shape: 900
# Element 1092 shape: 1080000
# Element 1093 shape: 900
# Element 1094 shape: 1080000
# Element 1095 shape: 900
# Element 1096 shape: 1080000
# Element 1097 shape: 900
# Element 1098 shape: 1080000
# Element 1099 shape: 900
# Element 1100 shape: 1080000
# Element 1101 shape: 900
# Element 1102 shape: 1080000
# Element 1103 shape: 900
# Element 1104 shape: 1080000
# Element 1105 shape: 900
# Element 1106 shape: 1080000
# Element 1107 shape: 900
# Element 1108 shape: 1080000
# Element 1109 shape: 900
# Element 1110 shape: 1080000
# Element 1111 shape: 900
# Element 1112 shape: 1080000
# Element 1113 shape: 900
# Element 1114 shape: 1080000
# Element 1115 shape: 900
# Element 1116 shape: 1080000
# Element 1117 shape: 900
# Element 1118 shape: 1080000
# Element 1119 shape: 900
# Element 1120 shape: 1080000
# Element 1121 shape: 900
# Element 1122 shape: 1080000
# Element 1123 shape: 900
# Element 1124 shape: 1080000
# Element 1125 shape: 900
# Element 1126 shape: 1080000
# Element 1127 shape: 900
# Element 1128 shape: 1080000
# Element 1129 shape: 900
# Element 1130 shape: 1080000
# Element 1131 shape: 900
# Element 1132 shape: 1080000
# Element 1133 shape: 900
# Element 1134 shape: 1080000
# Element 1135 shape: 900
# Element 1136 shape: 1080000
# Element 1137 shape: 900
# Element 1138 shape: 1080000
# Element 1139 shape: 900
# Element 1140 shape: 1080000
# Element 1141 shape: 900
# Element 1142 shape: 1080000
# Element 1143 shape: 900
# Element 1144 shape: 1080000
# Element 1145 shape: 900
# Element 1146 shape: 1080000
# Element 1147 shape: 900
# Element 1148 shape: 1080000
# Element 1149 shape: 900
# Element 1150 shape: 1080000
# Element 1151 shape: 900
# Element 1152 shape: 1080000
# Element 1153 shape: 900
# Element 1154 shape: 1080000
# Element 1155 shape: 900
# Element 1156 shape: 1080000
# Element 1157 shape: 900
# Element 1158 shape: 1080000
# Element 1159 shape: 900
# Element 1160 shape: 1080000
# Element 1161 shape: 900
# Element 1162 shape: 1080000
# Element 1163 shape: 900
# Element 1164 shape: 1080000
# Element 1165 shape: 900
# Element 1166 shape: 1080000
# Element 1167 shape: 900
# Element 1168 shape: 1080000
# Element 1169 shape: 900
# Element 1170 shape: 1080000
# Element 1171 shape: 900
# Element 1172 shape: 1080000
# Element 1173 shape: 900
# Element 1174 shape: 1080000
# Element 1175 shape: 900
# Element 1176 shape: 1080000
# Element 1177 shape: 900
# Element 1178 shape: 1080000
# Element 1179 shape: 900
# Element 1180 shape: 1080000
# Element 1181 shape: 900
# Element 1182 shape: 1080000
# Element 1183 shape: 900
# Element 1184 shape: 1080000
# Element 1185 shape: 900
# Element 1186 shape: 1080000
# Element 1187 shape: 900
# Element 1188 shape: 1080000
# Element 1189 shape: 900
# Element 1190 shape: 1080000
# Element 1191 shape: 900
# Element 1192 shape: 1080000
# Element 1193 shape: 900
# Element 1194 shape: 1080000
# Element 1195 shape: 900
# Element 1196 shape: 1080000
# Element 1197 shape: 900
# Element 1198 shape: 1080000
# Element 1199 shape: 900
# Element 1200 shape: 1080000
# Element 1201 shape: 900
# Element 1202 shape: 1080000
# Element 1203 shape: 900
# Element 1204 shape: 1080000
# Element 1205 shape: 900
# Element 1206 shape: 1080000
# Element 1207 shape: 900
# Element 1208 shape: 1080000
# Element 1209 shape: 900
# Element 1210 shape: 1080000
# Element 1211 shape: 900
# Element 1212 shape: 1080000
# Element 1213 shape: 900
# Element 1214 shape: 1080000
# Element 1215 shape: 900
# Element 1216 shape: 1080000
# Element 1217 shape: 900
# Element 1218 shape: 1080000
# Element 1219 shape: 900
# Element 1220 shape: 1080000
# Element 1221 shape: 900
# Element 1222 shape: 1080000
# Element 1223 shape: 900
# Element 1224 shape: 1080000
# Element 1225 shape: 900
# Element 1226 shape: 1080000
# Element 1227 shape: 900
# Element 1228 shape: 1080000
# Element 1229 shape: 900
# Element 1230 shape: 1080000
# Element 1231 shape: 900
# Element 1232 shape: 1080000
# Element 1233 shape: 900
# Element 1234 shape: 1080000
# Element 1235 shape: 900
# Element 1236 shape: 1080000
# Element 1237 shape: 900
# Element 1238 shape: 1080000
# Element 1239 shape: 900
# Element 1240 shape: 1080000
# Element 1241 shape: 900
# Element 1242 shape: 1080000
# Element 1243 shape: 900
# Element 1244 shape: 1080000
# Element 1245 shape: 900
# Element 1246 shape: 1080000
# Element 1247 shape: 900
# Element 1248 shape: 1080000
# Element 1249 shape: 900
# Element 1250 shape: 1080000
# Element 1251 shape: 900
# Element 1252 shape: 1080000
# Element 1253 shape: 900
# Element 1254 shape: 1080000
# Element 1255 shape: 900
# Element 1256 shape: 1080000
# Element 1257 shape: 900
# Element 1258 shape: 1080000
# Element 1259 shape: 900
# Element 1260 shape: 1080000
# Element 1261 shape: 900
# Element 1262 shape: 1080000
# Element 1263 shape: 900
# Element 1264 shape: 1080000
# Element 1265 shape: 900

# %%
labels[0:10]
# Out:
# [0.0,
#  0.07692307692307693,
#  0.15384615384615385,
#  0.23076923076923078,
#  0.3076923076923077,
#  0.38461538461538464,
#  0.46153846153846156,
#  0.5384615384615384,
#  0.6153846153846154,
#  0.6923076923076923]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.42, random_state=42)

print(f'shaep of x       : {x.shape}')
print(f'shaep of y       : {y.shape}')
print(f'shape of x_train : {x_train.shape} ')
print(f'shape of x_test  : {x_test.shape} ')
print(f'shape of y_train : {y_train.shape} ')
print(f'shape of y_test  : {y_test.shape} ')
# Out:
# shaep of x       : (633, 3240000)
# shaep of y       : (633,)
# shape of x_train : (367, 3240000)
# shape of x_test  : (266, 3240000)
# shape of y_train : (367,)
# shape of y_test  : (266,)

# %%
model = LinearRegression()
model.fit(x_train, y_train)

y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

print(f'MSE Training Set: {mse_train:.4f}')
print(f'MSE Testing Set: {mse_test:.4f}')
